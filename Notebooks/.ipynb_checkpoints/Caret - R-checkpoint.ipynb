# %% [markdown]
# # Caret - R

# %% [markdown]
# 1. Define Model
# 2. Define tuning parameter components
# 3. Define resampling method
# 4. Choose optimal based on performance

# %% [markdown]
# ## Data Split

# %% [markdown]
# in <- createdDataPartition(data,p=.75)
#
# training <- df[in,]
# test <- df[-in,]

# %% [markdown]
# ## Train Control

# %% [markdown]
# trainControl function allows resampling methods to be used to train models. Such as: "boot", "cv", "LOOCV", "LGOCV", "repeatedcv", "timeslice", "none" and "oob".
#
# Can also use custom peformance summary method via __summaryFunction__.
#
# summaryFunction = twoClassSummary, allows using metrics: sensitivity,specificty and ROC.
#
# __selectionFunction__: Function to determine final model parameters.
#
# __tolerance__: Function used to results with a chosen perc.

# %% [markdown]
# ## Pre process

# %% [markdown]
# Pre process class allows operations on predictors including centering and scaling. Can be interfaced through the train method.
#
# It centers and scales a variable to mean 0 and standard deviation 1. It ensures that the criterion for finding linear combinations of the predictors is based on how much variation they explain and therefore improves the numerical stability.

# %% [markdown]
# ## TuneGrid

# %% [markdown]
# Can take a dataframe with each col the tuning parameter of the method, the values being the values to use. Use the function expand.grid(par = c(), par2 = val). Param tuneGrid in train func.

# %% [markdown]
# ## Plotting

# %% [markdown]
# plot(fit) Shows the results against the different parameter values.
#
# bwolot() #box whisker
# dotplot()
# xyplot()
# splot() #Scatter plot

# %% [markdown]
# ## Predict

# %% [markdown]
# The predict function has two types class and prob.

# %% [markdown]
# ## Model Comparison/ Performance

# %% [raw]
# resamples() function compares fit of different models. Use summary() for a comparison.

# %% [markdown]
# confusionMatrix()
# postResample() #Defualt method
# twoClassSummary() #ROC
# prSummary() #AUC
# mnLogLoss() #Multi class multinominal log liklehood

# %% [markdown]
# Lift Curve - TBD
# Calibration curve - TBD

# %% [markdown]
# ## Feature Filter / Regularisation

# %% [markdown]
# ### Univarite Filters

# %% [markdown]
# Use stats to compare peformance with different predictors.
#
# sbf(predictors, outcome, sbfControl = sbfControl(),...)
#
# Uses __anova Score__ for each predictors (use multivariate to combine predictors). The mean predictor values are equal across the two classes.
#
# ctrl <- sbfControl(functions = rfSBF, method = "repeatedcv", repeats =5)

# %% [markdown]
# ## Recursive Feature Elimination

# %% [markdown]
# Default: The predictors are ranked then the model is fit for progressively less bottom ranked predictors. Optional to recaulate predictor ranking at every stage.
#
# Beaware of the pitfalls of overfitting using a single training set.
#
# Can choose elimination method, algo 1 : No resampling __refIter()__ and algo 2 : Resampling __rfe()__ .

# %% [markdown]
# __size__ : Param for subset sizes of predictors to be tested
#
# rfeControl$functions needs to be defined based on type of model.

# %% [markdown]
# ## Arbitary Model

# %% [markdown]
# If the list for rfeContol is not found one has to be created:

# %%
# A simple list example for random forests:

rfRFE <-  list(summary = defaultSummary,
               fit = function(x, y, first, last, ...){
                 library(randomForest)
                 randomForest(x, y, importance = first, ...)
                 },
               pred = function(object, x)  predict(object, x),
               rank = function(object, x, y) {
                 vimp <- varImp(object)
                 vimp <- vimp[order(vimp$Overall,decreasing = TRUE),,drop = FALSE]
                 vimp$var <- rownames(vimp)                  
                 vimp
                 },
               selectSize = pickSizeBest,
               selectVar = pickVars)

# %% [markdown]
# # Recipes

# %% [markdown]
# In place of x,y formula can use recipes for a wider more customisable set of pre processing and validation tools.
#
# List of uses for recipes:
#
# - Convert qualitative predictor to indicator variable
# - Transform data to diff scale
# - Extract key features from raw vars
#
# Possible step areas:
#
# - Impute (ie sub missing values with mean)
# - Individual transform (ie log)
# - Discretisation (Convert cont to discrete)
# - Dummy variables and encoding (ie create dummy var)
# - Predictor interactions
# - Normalisation (ie center)
# - Multivariate Transformation (ie PCA)
# - Filters (ie highly correlated)
# - Row operation (ie sort)
# - Others (ie rename)
# - Check (ie check for missing)
#
# Use tidy to force implement step

# %% [markdown]
# ## GLM Example

# %%
library(tidymodels)      # for the recipes package, along with the rest of tidymodels

# Helper packages
library(nycflights13)    # for flight data
library(skimr)           # for variable summaries

# %%
set.seed(123)

flight_data <- 
  flights %>% 
 mutate(
    # Convert the arrival delay to a factor
    arr_delay = ifelse(arr_delay >= 30, "late", "on_time"), #change vals to strings
    arr_delay = factor(arr_delay),
    # We will use the date (not date-time) in the recipe below
    date = lubridate::as_date(time_hour) #lubridate is R package for dates
  ) %>% 
  # Only retain the specific columns we will use
  select(dep_time, flight, origin, dest, air_time, distance, 
         carrier, date, arr_delay, time_hour) %>% 
  # Exclude missing data
  na.omit() %>% 
  # For creating models, it is better to have qualitative columns
  # encoded as factors (instead of character strings)
  mutate_if(is.character, as.factor)

flight_data

# %%
flight_data %>% 
  count(arr_delay) %>% 
  mutate(prop = n/sum(n)) #Creates table based on prev result

# %% [markdown]
# Flight number and time_hour are identifiers and not wanted in model training.

# %%
flight_data %>% 
  skimr::skim(dest, carrier)

# %%
# Fix the random numbers by setting the seed 
# This enables the analysis to be reproducible when random numbers are used 
set.seed(222)
# Put .75 of the data into the training set 
data_split <- initial_split(flight_data, prop = .75)

# Create data frames for the two sets:
train_data <- training(data_split)
test_data  <- testing(data_split)

# %%
#Instead of the standard model formula with ~, use a recipe:

flights_rec <- 
  recipe(arr_delay ~ ., data = train_data) %>%
  update_role(flight, time_hour, new_role = "ID") %>% #Dont use these two preds in model only for identification
  step_date(date, features = c("dow", "month")) %>%  #create new preds and adds to df             
  step_holiday(date, 
               holidays = timeDate::listHolidays("US"), 
               keep_original_cols = FALSE) %>% #Adds holidays to df, removes data col
  step_dummy(all_nominal_predictors()) %>% #Creates dummy var using selector for all nominal vals
  step_zv(all_predictors()) #Removes constant dummy var

# %% [markdown]
# Recipes do not auto convert factors into dummy numeric values, needs to be done manually! In this case there is a dest value only in the test set not in the training set, so will be given a constant dummy var during training. To avoid this useless predictor step_zv() removes constant pred cols.

# %%
#Use a model workflow to combine a model and recipe. (With caret can simply replace formula with recipe)

lr_mod <- 
  logistic_reg() %>% 
  set_engine("glm")

flights_wflow <- 
  workflow() %>% #Create workflow
  add_model(lr_mod) %>% 
  add_recipe(flights_rec)

flights_wflow

# %%
flights_fit <- 
  flights_wflow %>% 
  fit(data = train_data)

#predict(flights_fit, test_data)

# %% [markdown]
# # RFE Example

# %%
library(caret)
library(mlbench)
library(Hmisc)
library(randomForest)

# %%
n <- 100
p <- 40
sigma <- 1
set.seed(1)
sim <- mlbench.friedman1(n, sd = sigma) #Produces a X matrix and Y Vector
colnames(sim$x) <- c(paste("real", 1:5, sep = ""), #Create col names real1,real2 etc
                     paste("bogus", 1:5, sep = ""))
bogus <- matrix(rnorm(n * p), nrow = n)

colnames(bogus) <- paste("bogus", 5+(1:ncol(bogus)), sep = "") #Create 45 noise values

x <- cbind(sim$x, bogus)
y <- sim$y

# %%
normalization <- preProcess(x) #Defualt pre process is to center and scale

x <- predict(normalization, x)
x <- as.data.frame(x)

subsets <- c(1:5, 10, 15, 20, 25)

# %%
set.seed(10)

# Set func for linear models, 10 k folds (number)
ctrl <- rfeControl(functions = lmFuncs,
                   method = "repeatedcv",
                   number = 10,
                   repeats = 10,
                   verbose = FALSE)

lmProfile <- rfe(x, y,
                 sizes = subsets,
                 rfeControl = ctrl)

lmProfile

# %%
#Final model
lmProfile$fit

# %%
trellis.par.set(caretTheme())
plot(lmProfile, type = c("g", "o"))

# %%
lmProfile$resample

# %%
densityplot(lmProfile$resample)

# %% [markdown]
# # SVM Example

# %%
library(caret)
library(recipes)
library(dplyr)
library(QSARdata)

data(AquaticTox)
tox <- AquaticTox_moe2D
tox$Activity <- AquaticTox_Outcome$Activity
nrow(tox)

tox
# Out:
# Loading required package: ggplot2
#
# Loading required package: lattice
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘recipes’
#
#
# The following object is masked from ‘package:stats’:
#
#     step
# [1] 322
#     Molecule                                                 moeGao_Abra_L
# 1   (d)-limonene                                             4.729
# 2   111-trichloro-2-methyl-2-propanolol(chlorobytanol)       4.226
# 3   111-trichloroethane                                      2.790
# 4   1122-tetrachloroethane                                   3.636
# 5   112-trichloroethane                                      3.078
# 6   11-dichloroethylene(vinylidene                           2.225
# 7   1234-tetrachlorobenzene                                  5.945
# 8   123-trichlorobenzene                                     5.228
# 9   123-trichloropropane                                     3.742
# 10  1245-tetrachlorobenzene                                  6.026
# 11  124-trichlorobenzene                                     5.309
# 12  124-trimethyl                                            4.372
# 13  12-dichloro                                              2.520
# 14  12-dichloropropane                                       2.841
# 15  12-dimethylpropylamine(2-butanamine3-methyl)             2.872
# 16  12-propanediamine(12-diaminopropane)                     3.011
# 17  12-propyleneglycol                                       2.821
# 18  135-tribromo2-hydroxybenzene(246-tribromophenol)         6.913
# 19  135-trichlorobenzene                                     5.364
# 20  13-dibromopropane                                        3.821
# 21  13-dichloropropane                                       2.965
# 22  14-bis(chloromethyl)benzene                              5.590
# 23  14-dibromobenzene                                        5.448
# 24  14-dichlorobutane(butane1-4-dichloro)                    3.464
# 25  14-dimethoxybenzene                                      3.896
# 26  14-dioxane                                               2.844
# 27  15-dichloropentane                                       3.963
# 28  18-epoxy-p-menthane(eucalyptol)                          4.833
# 29  19-decadiene                                             4.550
# 30  1-(2-hydroxyethyl)piprazine-(1-piperazineethanol)        4.754
# ⋮   ⋮                                                        ⋮
# 293 p-t-butylstyrene(benzene1-(11-dimethylethyl)-4-ethynyl-) 5.373
# 294 p-tert-amylphenol                                        5.831
# 295 p-tert-butylphenol(butylphen)                            5.332
# 296 p-xylene                                                 3.896
# 297 pentabromophenol                                         9.122
# 298 pentachloroethane                                        4.249
# 299 pentachlorophenol                                        6.982
# 300 pentachloropyridine                                      6.767
# 301 pentafluoroaniline                                       3.579
# 302 pentafluorobenzaldehyde                                  3.701
# 303 pentanal                                                 2.912
# 304 phenol                                                   3.771
# 305 phenyl                                                   7.711
# 306 phthalazine                                              5.401
# 307 propargyl                                                1.965
# 308 propionitrile                                            2.039
# 309 pyridine                                                 3.049
# 310 quinoline                                                5.475
# 311 sec-butylamine                                           2.551
# 312 styrene                                                  3.812
# 313 tert-butylacetate                                        2.946
# 314 tert-octylamine(2-pentanamine                            3.901
# 315 tetrachloroethylene                                      3.832
# 316 tetrachlorophenol                                        6.265
# 317 tetrahydrofuran                                          2.485
# 318 thymol                                                   5.543
# 319 toluene                                                  3.420
# 320 trichloroethylene                                        3.119
# 321 trioxane(s-trioxane)                                     2.704
# 322 tripropylamine                                           4.487
#     moeGao_Abra_R moeGao_Abra_acidity moeGao_Abra_basicity moeGao_Abra_pi
# 1   0.512         0.030               0.126                0.330
# 2   0.527         0.375               0.452                0.712
# 3   0.383         0.030               0.101                0.469
# 4   0.496         0.168               0.078                0.577
# 5   0.401         0.099               0.081                0.509
# 6   0.412         0.030               0.076                0.407
# 7   1.196         0.030               0.093                0.904
# 8   1.061         0.030               0.131                0.852
# 9   0.430         0.049               0.108                0.559
# 10  1.196         0.030               0.039                0.947
# 11  1.061         0.030               0.077                0.895
# 12  0.680         0.030               0.125                0.505
# 13  0.306         0.030               0.084                0.441
# 14  0.291         0.049               0.102                0.402
# 15  0.199         0.207               0.595                0.299
# 16  0.403         0.384               1.051                0.588
# 17  0.341         0.631               0.703                0.717
# 18  1.653         0.639               0.206                1.229
# 19  1.061         0.030               0.034                0.900
# 20  0.640         0.030               0.049                0.599
# 21  0.294         0.030               0.071                0.441
# 22  0.926         0.030               0.115                0.843
# 23  1.272         0.030               0.070                1.001
# 24  0.294         0.030               0.071                0.441
# 25  0.672         0.030               0.106                0.529
# 26  0.274         0.030               0.733                0.647
# 27  0.294         0.030               0.071                0.441
# 28  0.412         0.030               0.508                0.415
# 29  0.294         0.030               0.131                0.207
# 30  0.696         0.452               1.572                0.943
# ⋮   ⋮             ⋮                   ⋮                    ⋮
# 293 0.778         0.030               0.203                0.490
# 294 0.816         0.573               0.480                0.772
# 295 0.816         0.573               0.480                0.772
# 296 0.672         0.030               0.129                0.529
# 297 2.269         0.758               0.139                1.448
# 298 0.617         0.099               0.104                0.694
# 299 1.404         0.758               0.194                1.053
# 300 1.309         0.030               0.365                1.129
# 301 0.341         0.277               0.292                0.899
# 302 0.205         0.030               0.343                1.017
# 303 0.171         0.030               0.423                0.622
# 304 0.829         0.573               0.433                0.875
# 305 1.600         0.155               0.424                1.404
# 306 1.440         0.030               0.685                1.289
# 307 0.389         0.457               0.434                0.592
# 308 0.184         0.030               0.348                0.930
# 309 0.634         0.030               0.447                0.750
# 310 1.370         0.030               0.507                1.092
# 311 0.214         0.207               0.577                0.338
# 312 0.791         0.030               0.156                0.593
# 313 0.285         0.030               0.475                0.479
# 314 0.187         0.207               0.661                0.219
# 315 0.666         0.030               0.043                0.707
# 316 1.269         0.758               0.209                1.001
# 317 0.261         0.030               0.402                0.462
# 318 0.830         0.573               0.443                0.788
# 319 0.664         0.030               0.133                0.553
# 320 0.548         0.049               0.068                0.624
# 321 0.287         0.030               1.064                0.832
# 322 0.156         0.030               0.745                0.375
#     moe2D_BCUT_PEOE_0 moe2D_BCUT_PEOE_1 moe2D_BCUT_PEOE_2 moe2D_BCUT_PEOE_3 ⋯
# 1   -2.696            -0.009128         0.04606           2.639             ⋯
# 2   -2.556            -0.080280         0.05082           2.615             ⋯
# 3   -2.262            -0.083670         0.02702           2.350             ⋯
# 4   -2.235            -0.101800         0.01105           2.377             ⋯
# 5   -2.260            -0.091020         0.03334           2.350             ⋯
# 6   -1.806            -0.415800         0.40630           1.820             ⋯
# 7   -2.089            -0.686300         0.65950           2.130             ⋯
# 8   -2.104            -0.680300         0.67320           2.116             ⋯
# 9   -2.422            -0.067810         0.04442           2.479             ⋯
# 10  -2.087            -0.678900         0.65340           2.129             ⋯
# 11  -2.103            -0.671500         0.66460           2.114             ⋯
# 12  -2.381            -0.113400         0.14790           2.318             ⋯
# 13  -2.285            -0.068550         0.04410           2.323             ⋯
# 14  -2.441            -0.057240         0.03772           2.460             ⋯
# 15  -2.680             0.023280         0.11850           2.609             ⋯
# 16  -2.588            -0.174000         0.29490           2.507             ⋯
# 17  -2.499            -0.475400         0.60840           2.494             ⋯
# 18  -2.127            -0.665200         0.68230           2.136             ⋯
# 19  -2.102            -0.677800         0.67080           2.114             ⋯
# 20  -2.457            -0.048320         0.03822           2.443             ⋯
# 21  -2.448            -0.068990         0.04298           2.452             ⋯
# 22  -2.307            -0.265000         0.26460           2.285             ⋯
# 23  -2.124            -0.657400         0.67670           2.092             ⋯
# 24  -2.542            -0.069000         0.04294           2.523             ⋯
# 25  -2.280            -0.586500         0.47890           2.220             ⋯
# 26  -2.588            -0.159700         0.05826           2.555             ⋯
# 27  -2.601            -0.069000         0.04294           2.566             ⋯
# 28  -2.915             0.025730         0.03947           2.878             ⋯
# 29  -2.667            -0.658000         0.68660           2.600             ⋯
# 30  -2.754            -0.457500         0.46200           2.650             ⋯
# ⋮   ⋮                 ⋮                 ⋮                 ⋮                 ⋱
# 293 -2.632            -0.40220           0.43250          2.576             ⋯
# 294 -2.676            -0.38420           0.41920          2.621             ⋯
# 295 -2.631            -0.40100           0.43420          2.577             ⋯
# 296 -2.327            -0.20650           0.25110          2.262             ⋯
# 297 -2.106            -0.68780           0.65800          2.158             ⋯
# 298 -2.211            -0.09357          -0.01884          2.404             ⋯
# 299 -2.092            -0.70260           0.64660          2.176             ⋯
# 300 -2.009            -0.65640           0.61520          2.114             ⋯
# 301 -2.125            -0.73040           0.55990          2.252             ⋯
# 302 -2.038            -0.73110           0.55730          2.262             ⋯
# 303 -2.570            -0.15710           0.03387          2.531             ⋯
# 304 -2.159            -0.64380           0.70220          2.102             ⋯
# 305 -2.206            -0.62410           0.67490          2.224             ⋯
# 306 -2.155            -0.58300           0.59290          2.125             ⋯
# 307 -2.120            -0.54940           0.57730          2.103             ⋯
# 308 -2.307            -0.16350           0.16410          2.319             ⋯
# 309 -2.086            -0.59250           0.67540          2.034             ⋯
# 310 -2.171            -0.62810           0.66890          2.129             ⋯
# 311 -2.616             0.02303           0.11850          2.539             ⋯
# 312 -2.196            -0.64860           0.69800          2.124             ⋯
# 313 -2.600             0.02573           0.03302          2.588             ⋯
# 314 -2.783             0.02349           0.02878          2.717             ⋯
# 315 -1.756            -0.41140           0.32690          1.873             ⋯
# 316 -2.106            -0.68800           0.66250          2.160             ⋯
# 317 -2.435            -0.15820           0.05596          2.625             ⋯
# 318 -2.536            -0.23130           0.36220          2.491             ⋯
# 319 -2.277            -0.56290           0.62070          2.213             ⋯
# 320 -1.781            -0.41390           0.36680          1.846             ⋯
# 321 -2.482            -0.18530           0.08730          2.445             ⋯
# 322 -2.724             0.02302           0.04264          2.616             ⋯
#     moe2D_vdw_vol moe2D_vsa_acc moe2D_vsa_don moe2D_vsa_hyd moe2D_vsa_other
# 1   232.50        0.000         0             158.10         0.000
# 2   168.00        0.000         0             147.60         0.000
# 3   110.60        0.000         0             118.20         0.000
# 4   126.60        0.000         0             118.30        13.660
# 5   110.60        0.000         0             106.90         6.831
# 6    88.76        0.000         0              88.57         6.831
# 7   192.70        0.000         0             168.00         0.000
# 8   176.70        0.000         0             149.70         0.000
# 9   135.10        0.000         0             129.50         0.000
# 10  192.70        0.000         0             168.00         0.000
# 11  176.70        0.000         0             149.70         0.000
# 12  202.20        0.000         0             142.30         0.000
# 13   94.67        0.000         0              95.40         0.000
# 14  119.10        0.000         0             111.20         0.000
# 15  150.70        0.000         0              97.13         0.000
# 16  116.50        0.000         0              56.41         0.000
# 17  104.20        0.000         0              59.93         0.000
# 18  224.40        0.000         0             177.70         0.000
# 19  176.70        0.000         0             149.70         0.000
# 20  145.20        0.000         0             134.80         0.000
# 21  119.10        0.000         0             111.20         0.000
# 22  209.60        0.000         0             163.10         0.000
# 23  186.80        0.000         0             155.00         0.000
# 24  143.50        0.000         0             127.00         0.000
# 25  199.10        5.008         0             151.50         0.000
# 26  119.00        5.008         0              88.23         0.000
# 27  168.00        0.000         0             142.80         0.000
# 28  241.10        2.504         0             153.70         0.000
# 29  246.40        0.000         0             185.30         0.000
# 30  189.30        0.000         0             123.60         0.000
# ⋮   ⋮             ⋮             ⋮             ⋮             ⋮
# 293 269.50         0.000         0.00         201.10         0.000
# 294 259.50         0.000         0.00         177.90         0.000
# 295 235.10         0.000         0.00         162.10         0.000
# 296 177.70         0.000         0.00         126.50         0.000
# 297 282.30         0.000         0.00         237.80         0.000
# 298 142.50         0.000         0.00         147.90         6.831
# 299 217.20         0.000         0.00         179.00         0.000
# 300 199.60         5.683         0.00         161.50        18.020
# 301 159.30         0.000        17.74         111.30         0.000
# 302 170.20        13.570         0.00         106.90        22.060
# 303 137.20        13.570         0.00          76.83        22.060
# 304 137.40         0.000         0.00          87.50         0.000
# 305 288.60        13.570         0.00         161.40        17.210
# 306 181.90        18.840         0.00         108.30         0.000
# 307  83.90         0.000         0.00          67.28         0.000
# 308  88.18        17.740         0.00          45.22        20.300
# 309 119.80         5.683         0.00          88.02         0.000
# 310 191.80         5.683         0.00         124.10         0.000
# 311 126.30         0.000         0.00          81.32         0.000
# 312 171.80         0.000         0.00         126.50         0.000
# 313 172.30        13.570         0.00         117.60        17.210
# 314 224.00         0.000         0.00         162.90         0.000
# 315 120.70         0.000         0.00         118.30        13.660
# 316 201.20         0.000         0.00         160.70         0.000
# 317 108.40         2.504         0.00          75.73         0.000
# 318 235.10         0.000         0.00         150.70         0.000
# 319 153.30         0.000         0.00         110.70         0.000
# 320 104.70         0.000         0.00         106.90         6.831
# 321 105.30         7.511         0.00           0.00        84.930
# 322 251.70         0.000         0.00         196.50         0.000
#     moe2D_vsa_pol moe2D_weinerPath moe2D_weinerPol moe2D_zagreb Activity
# 1    0.000        120              11              46           5.29
# 2   13.570         58               9              38           3.12
# 3    0.000         16               0              20           3.40
# 4    0.000         29               4              22           3.92
# 5    0.000         18               2              16           3.21
# 6    0.000          9               0              12           2.84
# 7    0.000        109              14              48           5.29
# 8    0.000         82              11              42           4.89
# 9    0.000         31               4              20           3.41
# 10   0.000        111              13              48           5.83
# 11   0.000         84              10              42           4.80
# 12   0.000         84              10              42           4.19
# 13   0.000         10               1              10           2.90
# 14   0.000         18               2              16           2.93
# 15  17.740         29               4              22           2.49
# 16  35.480         18               2              16           1.81
# 17  27.130         18               2              16           0.13
# 18  13.570        110              13              48           4.71
# 19   0.000         84               9              42           4.74
# 20   0.000         20               2              14           5.05
# 21   0.000         20               2              14           2.94
# 22   0.000        125              11              44           6.65
# 23   0.000         62               7              36           5.28
# 24   0.000         35               3              18           3.39
# 25   5.008        125              11              44           3.07
# 26   5.008         27               3              24           0.93
# 27   0.000         56               4              22           3.75
# 28   2.504        128              16              64           3.18
# 29   0.000        165               7              34           5.68
# 30  19.250         94               8              38           1.31
# ⋮   ⋮             ⋮                ⋮               ⋮            ⋮
# 293  0.000        201              15              58           3.51
# 294 13.570        195              16              58           4.80
# 295 13.570        152              13              54           4.47
# 296  0.000         62               7              36           4.21
# 297 13.570        174              21              60           6.72
# 298  0.000         42               6              30           4.43
# 299 13.570        174              21              60           6.04
# 300  5.683        140              17              54           5.73
# 301 17.740        174              21              60           3.69
# 302 13.570        220              23              64           5.25
# 303 13.570         35               3              18           3.82
# 304 13.570         42               5              30           3.50
# 305 27.130        459              21              78           5.27
# 306 18.840        109              12              50           3.11
# 307 13.570         10               1              10           4.56
# 308 17.740         10               1              10           1.56
# 309  5.683         27               3              24           2.90
# 310  5.683        109              12              50           3.45
# 311 17.740         18               2              16           2.42
# 312  0.000         64               7              34           3.51
# 313 13.570         66               5              34           2.55
# 314 17.740         88               6              42           3.72
# 315  0.000         29               4              22           3.91
# 316 13.570        140              17              54           6.13
# 317  2.504         15               0              20           1.52
# 318 13.570        150              14              52           4.67
# 319  0.000         42               5              30           3.42
# 320  0.000         18               2              16           3.47
# 321  7.511         27               3              24           1.18
# 322  0.000        138               9              36           3.45

# %%
tox <- tox %>%
  select(-Molecule) %>%
  ## Suppose the easy of manufacturability is 
  ## related to the molecular weight of the compound
  mutate(manufacturability  = 1/moe2D_Weight) %>%
  mutate(manufacturability = manufacturability/sum(manufacturability))

# %%
#Function to calculate RMSE

model_stats <- function(data, lev = NULL, model = NULL) {
  
  stats <- defaultSummary(data, lev = lev, model = model)
  
  wt_rmse <- function (pred, obs, wts, na.rm = TRUE) 
  sqrt(weighted.mean((pred - obs)^2, wts, na.rm = na.rm))
  
  res <- wt_rmse(pred = data$pred,
                 obs = data$obs, 
                 wts = data$manufacturability)
  c(wRMSE = res, stats)
}

# %%
tox_recipe <- recipe(Activity ~ ., data = tox) %>%
#   add_role(manufacturability, new_role = "performance var") %>%
  step_nzv(all_predictors()) %>% #Remove sparse and unbalanced preds
  #Reduce dimension of vsa cols into surf_area.. cols
  step_pca(contains("VSA"), prefix = "surf_area_",  threshold = .95) %>%
  #Remove closely corr pred except from surf_area
  step_corr(all_predictors(), -starts_with("surf_area_"), threshold = .90) %>%
  # Center and scale
  step_center(all_predictors()) %>%
  step_scale(all_predictors())

# %%
tox_ctrl <- trainControl(method = "cv")
set.seed(888)
# tox_svm <- train(x, y,
#                  method = "svmRadial", 
#                  metric = "wRMSE",
#                  maximize = FALSE,
#                  tuneLength = 10,
#                  trControl = tox_ctrl,
#                 tuneGrid = expand.grid(C=seq(10,20,length=10),sigma=0.01150696))

# tox_svm

caretFuncs$fit <- function(x,y,first,last,...) train(x, y,
                 method = "svmRadial", 
                 maximize = FALSE,
                 tuneLength = 10,
                 trControl = tox_ctrl,
                tuneGrid = expand.grid(C=12,sigma=0.01150696))


ctrl <- rfeControl(functions = caretFuncs,
                   method = "repeatedcv",
                   repeats = 5,
                   verbose = FALSE)

svmProfile <- rfe(tox_recipe,
                  data = tox,
                 sizes = 2:30,
                 rfeControl = ctrl)

svmProfile
# Out:
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33036”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16727”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  3.2209e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.48076”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00075816”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.48076”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027535”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32498”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16663”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  3.2209e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.12468”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.15113”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.1413e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.31844”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.17133”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.6285e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.48488”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00073037”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.48488”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027025”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32183”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.17416”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  8.7085e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47912”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00074431”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47912”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027282”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.4288”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.2031”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.0462e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.13236”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.15405”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.7127e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.46733”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00079207”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.46733”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.028144”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.45143”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.20285”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.8971e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.49015”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00076415”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.49015”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027643”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47202”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00061874”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47202”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.024875”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33791”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16621”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.0538e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47731”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00076458”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47731”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027651”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32245”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16896”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.6285e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.13683”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.15754”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1.3115e-16”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.46823”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00074914”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.46823”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.02737”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33334”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16843”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  3.2209e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47221”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00081586”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47221”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.028563”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33039”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16763”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.5561e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47607”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00074355”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47607”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027268”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.46121”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00074542”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.46121”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027302”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.31709”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.1726”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.4615e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32085”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16936”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  3.2209e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47624”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00076697”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47624”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027694”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.66061”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.27472”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  3.2209e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47433”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00075131”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47433”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.02741”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32771”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.1683”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.10796”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16824”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.1413e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47485”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00073667”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47485”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027142”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33026”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16689”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  8.7085e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47759”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00072644”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47759”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.026953”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.48315”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.0005721”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.48315”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.023919”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32088”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16818”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.8971e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.11499”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.15103”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1.3067e-16”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.46654”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00075327”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.46654”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027446”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.3164”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.17001”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.4615e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47221”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00077009”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47221”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.02775”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.4441”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.20655”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  8.7085e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.46535”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00077375”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.46535”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027816”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32154”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16944”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.6285e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.49132”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00072295”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.49132”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.026888”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.46771”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00088587”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.46771”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.029764”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47674”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00064882”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47674”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.025472”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32898”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.17075”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  3.2209e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.55967”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 1.5254”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 2.2627”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33711”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.1657”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.6285e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.56084”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 1.5306”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 2.2784”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.46737”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.0007622”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.46737”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027608”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33037”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16786”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47895”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00073421”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47895”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027096”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33273”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16605”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.8971e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.13083”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.15049”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.1413e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47682”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00076008”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47682”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.02757”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.4563”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.20241”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  8.7085e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.56557”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 1.5742”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.5989e-16”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 2.4114”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.48259”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00076208”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.48259”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027606”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.3305”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16606”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.3091e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.12082”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16067”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.5476e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.31791”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16957”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.5561e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47534”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00081349”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47534”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.028522”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32166”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.17127”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.6285e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.31109”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.17129”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.0538e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.46107”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.0007822”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.46107”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027968”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# ...
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32399”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16654”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  3.2209e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.56143”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 1.531”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 2.2796”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.12786”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.15189”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.3147”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.17045”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  8.7085e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47638”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00074111”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47638”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027223”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33192”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16785”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.0462e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47592”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00072951”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47592”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027009”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.44661”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.19982”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47997”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00072553”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47997”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.026936”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33347”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16595”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.0538e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47237”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00078117”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47237”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027949”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.33602”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.16621”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.0462e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.47197”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00073903”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.47197”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027185”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.44555”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.20716”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.8971e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.48534”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00061633”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.48534”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.024826”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.32078”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.17159”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  5.8971e-18”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.56622”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 1.5859”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  8.3362e-16”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 2.4474”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.4891”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00073378”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.4891”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.027088”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Recursive feature selection
#
# Outer resampling method: Cross-Validated (10 fold, repeated 5 times)
#
# Resampling performance over subset size:
#
#  Variables   RMSE Rsquared    MAE RMSESD RsquaredSD   MAESD Num_Resamples
#          2 0.7439   0.6774 0.5564 0.1311    0.09716 0.09472            50
#          3 0.7456   0.6778 0.5571 0.1306    0.09399 0.09159            50
#          4 0.7385   0.6822 0.5397 0.1317    0.09453 0.09676            50
#          5 0.7324   0.6887 0.5354 0.1300    0.09185 0.09186            50
#          6 0.7267   0.6929 0.5305 0.1289    0.09072 0.09038            50
#          7 0.7257   0.6934 0.5293 0.1287    0.09140 0.09002            50
#          8 0.7225   0.6969 0.5298 0.1227    0.08749 0.08759            50
#          9 0.7180   0.7012 0.5236 0.1239    0.08653 0.08731            50
#         10 0.7218   0.6986 0.5225 0.1259    0.08777 0.08811            50
#         11 0.7224   0.6988 0.5213 0.1268    0.08827 0.08798            50
#         12 0.7177   0.7032 0.5151 0.1243    0.08292 0.08371            50
#         13 0.7197   0.7013 0.5158 0.1236    0.08285 0.08203            50
#         14 0.7148   0.7065 0.5075 0.1233    0.08002 0.08199            50
#         15 0.7051   0.7142 0.4968 0.1230    0.07643 0.08267            50
#         16 0.7001   0.7184 0.4883 0.1278    0.07772 0.08300            50
#         17 0.6998   0.7180 0.4891 0.1264    0.07777 0.08305            50
#         18 0.7027   0.7155 0.4923 0.1262    0.07774 0.08415            50
#         19 0.7056   0.7136 0.4965 0.1244    0.07636 0.08105            50
#         20 0.7030   0.7158 0.4958 0.1247    0.07680 0.08084            50
#         21 0.7022   0.7163 0.4952 0.1250    0.07842 0.08094            50
#         22 0.7050   0.7149 0.4985 0.1262    0.07956 0.08254            50
#         23 0.7065   0.7143 0.4999 0.1272    0.07953 0.08138            50
#         24 0.7106   0.7112 0.5025 0.1261    0.07872 0.08161            50
#         25 0.7124   0.7096 0.5036 0.1251    0.07797 0.08134            50
#         26 0.7135   0.7080 0.5025 0.1258    0.07872 0.08139            50
#         27 0.7101   0.7099 0.5004 0.1216    0.07644 0.07876            50
#         28 0.7080   0.7122 0.4956 0.1206    0.07460 0.07717            50
#         29 0.7044   0.7162 0.4895 0.1233    0.07437 0.08113            50
#         30 0.6928   0.7247 0.4810 0.1250    0.07470 0.08370            50
#         72 0.5739   0.8166 0.3628 0.1004    0.03699 0.05655             4
#         73 0.6128   0.7795 0.4022 0.1012    0.07520 0.06144             7
#         74 0.6304   0.7515 0.4215 0.1461    0.09958 0.07342            20
#         75 0.6057   0.7977 0.4119 0.1151    0.06970 0.08411            16
#  Selected
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         *
#
#
#
#
#
# The top 5 variables (out of 30):
#    moe2D_SlogP, moe2D_Weight, manufacturability, moe2D_a_hyd, moe2D_chi0v
